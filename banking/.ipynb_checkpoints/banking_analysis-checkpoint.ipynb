# %%
import pandas as pd
import sqlalchemy as sa
import urllib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define your connection parameters
params = urllib.parse.quote_plus(
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=localhost;"  # Or your specific IP address
    "Database=banking_cases;"
    "UID=sa;"            # Default user for Docker MSSQL
    "PWD=Password92;"
    "Encrypt=yes;"
    "TrustServerCertificate=yes;"
)

# Create the engine
engine = sa.create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

print(engine)

df = pd.read_sql("SELECT * FROM customer", engine)
df.head()
# Out:
# Engine(mssql+pyodbc:///?odbc_connect=Driver%3D%7BODBC+Driver+18+for+SQL+Server%7D%3BServer%3Dlocalhost%3BDatabase%3Dbanking_cases%3BUID%3Dsa%3BPWD%3DPassword92%3BEncrypt%3Dyes%3BTrustServerCertificate%3Dyes%3B)
#   Client_ID             Name  Age  Location_ID Joined_Bank   Banking_Contact  \
# 0  IND81288    Raymond Mills   24        34324  2019-05-06    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  2001-12-10  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  2010-01-25     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  2019-03-28        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  2012-07-20        Shawn Long
#
#   Nationality            Occupation Fee_Structure Loyalty_Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client_ID                 3000 non-null   str
#  1   Name                      3000 non-null   str
#  2   Age                       3000 non-null   int64
#  3   Location_ID               3000 non-null   int64
#  4   Joined_Bank               3000 non-null   object
#  5   Banking_Contact           3000 non-null   str
#  6   Nationality               3000 non-null   str
#  7   Occupation                3000 non-null   str
#  8   Fee_Structure             3000 non-null   str
#  9   Loyalty_Classification    3000 non-null   str
#  10  Estimated_Income          3000 non-null   float64
#  11  Superannuation_Savings    3000 non-null   float64
#  12  Amount_of_Credit_Cards    3000 non-null   int64
#  13  Credit_Card_Balance       3000 non-null   float64
# ...

# %%
df.describe()
# Out:
#                Age   Location_ID  Estimated_Income  Superannuation_Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034184            25531.599685
# std      19.854760  12462.273017     111935.808180            16259.950768
# min      17.000000     12.000000      15919.480469             1482.030029
# 25%      34.000000  10803.500000      82906.597656            12513.774902
# 50%      51.000000  21129.500000     142313.476562            22357.355469
# 75%      69.000000  32054.500000     242290.300781            35464.741211
# max      85.000000  43369.000000     522330.250000            75963.898438
#
#        Amount_of_Credit_Cards  Credit_Card_Balance    Bank_Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206944  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
 df.columns = df.columns.str.lower()

# %%
df
# Out:
#      client_id              name  age  location_id joined_bank  \
# 0     IND81288     Raymond Mills   24        34324  2019-05-06
# 1     IND65833     Julia Spencer   23        42205  2001-12-10
# 2     IND47499    Stephen Murray   27         7314  2010-01-25
# 3     IND72498    Virginia Garza   40        34594  2019-03-28
# 4     IND60181   Melissa Sanders   46        41269  2012-07-20
# ...        ...               ...  ...          ...         ...
# 2995  IND66827         Earl Hall   82         8760  2014-10-09
# 2996  IND40556  Billy Williamson   44        32837  2009-02-05
# 2997  IND72414      Victor Black   70        36088  2009-12-29
# 2998  IND46652       Andrew Ford   56        24871  2006-02-13
# 2999  IND40216        Amy Nguyen   79        38518  2005-12-08
#
#           banking_contact nationality                     occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %%
icome_bins = [0,100000,300000,float('inf')]
labels=['Low','Medium','High']
df['income_band']=pd.cut(df['estimated_income'],bins=icome_bins,labels=labels,right=False)

# %%
df['income_band'].value_counts()
# Out:
# income_band
# Medium    1517
# Low       1027
# High       456
# Name: count, dtype: int64

# %%
df['income_band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='income_band'>

# %%
 df.columns
# Out:
# Index(['client_id', 'name', 'age', 'location_id', 'joined_bank',
#        'banking_contact', 'nationality', 'occupation', 'fee_structure',
#        'loyalty_classification', 'estimated_income', 'superannuation_savings',
#        'amount_of_credit_cards', 'credit_card_balance', 'bank_loans',
#        'bank_deposits', 'checking_accounts', 'saving_accounts',
#        'foreign_currency_account', 'business_lending', 'properties_owned',
#        'risk_weighting', 'brid', 'genderid', 'iaid', 'income_band'],
#       dtype='str')

# %%
categorical_coluumns = df[['brid', 'genderid', 'iaid', 'amount_of_credit_cards', 'nationality', 'occupation', 'fee_structure', 'properties_owned', 'loyalty_classification', 'risk_weighting', 'income_band']].columns

for cols in categorical_coluumns:
    print(f"Value counts for '{cols}':")
    display(df[cols].value_counts() )
    print("\n\n\n\n")
# Out:
# Value counts for 'brid':
# brid
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
# Value counts for 'genderid':
# genderid
# 2    1512
# 1    1488
# Name: count, dtype: int64
# Value counts for 'iaid':
# iaid
# 1     177
# 2     177
# 3     177
# 4     177
# 8     177
# 9     176
# 10    176
# 11    176
# 12    176
# 13    176
# 14    176
# 15    176
# 5      89
# 6      89
# 7      89
# 16     88
# 17     88
# 18     88
# 19     88
# 20     88
# 21     88
# 22     88
# Name: count, dtype: int64
# Value counts for 'amount_of_credit_cards':
# amount_of_credit_cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# Value counts for 'nationality':
# nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value counts for 'occupation':
# occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# ...

# %%
for i, predictor in enumerate(categorical_coluumns):
   plt.figure(i)
   sns.countplot(data=df, x=predictor, hue='genderid' )

# %%
for i, predictor in enumerate(categorical_coluumns):
   plt.figure(i)
   sns.countplot(data=df, x=predictor, hue='nationality' )

# %%
for cols in categorical_coluumns:
    if cols == 'occupation':
        continue
    plt.figure(figsize = (8,4))
    sns.histplot(df[cols])
    plt.title(f"Histogram for {cols}")
    plt.xlabel(cols)
    plt.ylabel("Count")
    plt.show()

# %%
df.columns
# Out:
# Index(['client_id', 'name', 'age', 'location_id', 'joined_bank',
#        'banking_contact', 'nationality', 'occupation', 'fee_structure',
#        'loyalty_classification', 'estimated_income', 'superannuation_savings',
#        'amount_of_credit_cards', 'credit_card_balance', 'bank_loans',
#        'bank_deposits', 'checking_accounts', 'saving_accounts',
#        'foreign_currency_account', 'business_lending', 'properties_owned',
#        'risk_weighting', 'brid', 'genderid', 'iaid', 'income_band'],
#       dtype='str')

# %%
numerical_columns = df[['estimated_income', 'superannuation_savings','credit_card_balance', 'bank_loans','bank_deposits', 'checking_accounts', 'saving_accounts', 'foreign_currency_account', 'business_lending']].columns
for i, predictor in enumerate(numerical_columns):
    
    sns.histplot(df[predictor], kde = True)
    plt.title(predictor)
    plt.show()

# %%
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize = (12,12))
sns.heatmap(correlation_matrix, annot= True, cmap = 'crest', fmt = ".2f")
plt.title("correlation matrix")
plt.show()
